# %%
from faker import Faker
import pandas as pd
import random

# %%
fake = Faker()
Faker.seed(9999)
contacts = pd.read_csv('contacts.csv')
header = ["First", "Last", "Age", "Phone", "E-mail", "Address"]

# %%
first = [fake.first_name() for i in range(500)]
last = [fake.last_name() for i in range(500)]
age = [random.randint(18, 100) for i in range(500)]
phone = [fake.phone_number() for i in range(500)]
email = [fake.email() for i in range(500)]
address = [fake.address() for i in range(500)]
# contact_info = pd.DataFrame(data=[first, last, age, phone, email, address], index=[0], columns=header)
contact_info = pd.DataFrame(data={'First': first,
                                 'Last' : last,
                                 'Age': age,
                                 'Phone': phone,
                                 'E-mail': email,
                                 'Address': address}, columns=header)
contact_info.to_csv('contacts.csv',mode='a',index=False, header=False)

# %%
contacts
# Out:
#         First        Last  Age                  Phone  \
# 0    Danielle  Hutchinson   79  +1-392-365-2501x53977
# 1     Marissa     Cochran   52     (948)872-6864x1278
# 2      Calvin      Newman   35          (737)726-5545
# 3       Diana     Simmons  100           689-912-0645
# 4        Dale      Hurley   22     (149)105-2426x0348
# ..        ...         ...  ...                    ...
# 495    Jeremy     Escobar   95             6700915337
# 496   Melanie      Brewer   48      582-908-5194x6252
# 497   Douglas      Rangel   47          (747)576-4062
# 498   Allison    Williams   23   +1-420-070-0980x1886
# 499    Bianca       Jones   87       468.377.0229x947
#
#                           E-mail  \
# 0              okoch@example.org
# 1            vrivera@example.org
# 2             yevans@example.com
# 3       gouldstephen@example.org
# 4        greenthomas@example.com
# ..                           ...
# 495           ppratt@example.org
# 496           ismith@example.com
# 497      brewerlarry@example.com
# 498  veronicacoleman@example.net
# 499         wjohnson@example.org
#
#                                                Address
# 0             326 Jenny Garden\nLake Miranda, MA 94299
# 1            9081 Jackson Freeway\nJamestown, ID 05820
# 2                          USCGC Ramirez\nFPO AE 23443
# 3                 2927 Paul Dale\nHowardside, MI 10054
# 4           5921 Burch Throughway\nEast Eric, ID 92175
# ..                                                 ...
# 495                          USS Freeman\nFPO AE 17305
# 496  832 Cameron Glen Apt. 274\nMichaelchester, NM ...
# 497  76240 Parker Junctions Suite 649\nLeeberg, SC ...
# 498   305 Jason Stream\nEast Veronicaborough, MA 40274
# 499              492 Beltran Well\nGreenside, OR 01628
#
# [500 rows x 6 columns]
